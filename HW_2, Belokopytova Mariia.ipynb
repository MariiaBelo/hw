# %% [markdown]
# ## Класс человека
# Моделирование человека — классическое упражнение для людей, которые пытаются научиться писать классы. Мы все знакомы с характеристиками и поведением людей, поэтому стоит попробовать это упражнение.
# * Определите класс Person().
# * В функции __init()__ определите несколько атрибутов человека. Хорошими атрибутами, которые следует учитывать, являются имя, возраст, место рождения и все, что вам нужно знать о людях в вашей жизни. Не менее 3 атрибутов.
# * Напишите один метод. Это может быть просто introduce_yourself(). Этот метод выводит такое утверждение, как «Здравствуйте, меня зовут Эрик».
# * Вы также можете создать такой метод, как age_person(). Простая версия этого метода просто добавит 1 к возрасту человека.
# * Создайте человека, установите соответствующие значения атрибутов и выведите информацию о человеке.
# * Вызовите свой метод для человека, которого вы создали. Убедитесь, что ваш метод выполняется правильно; если метод ничего не выводит напрямую, напечатайте что-нибудь до и после вызова метода, чтобы убедиться, что он сделал то, что предполагалось.

# %%
class Person():
    
    def __init__(self, name="Harry", age=11, citizenship= "Little Whinging", profession="Boy-Who-Lived", fav_food="Dursley's Blood"):
        self.name = name
        self.age = age
        self.citizenship = citizenship
        self.profession = profession
        self.fav_food = fav_food
    def introduce_yourself(self):
        iy=print("Hey, my name is %s, I was born in %s and I'm %d years old.\nFashion is my profession, but I'm also a %s. I can eat %s all the time."%(self.name, self.citizenship, self.age, self.profession,self.fav_food))
        return iy
    def comparing(self,other_person):
        if self.age==other_person.age:
            a=print("%s and %s are the same age"%(self.name,other_person.name))
            
        else:
            if self.age>other_person.age:
                dif=self.age-other_person.age
                a=print("%s is %d years older than %s"%(self.name,dif,other_person.name))
                
            else:
                dif=other_person.age-self.age
                a=print("%s is %d years younger than %s"%(self.name,dif,other_person.name))
        return a
    def age_person(self):
        self.age+=1
            
            
my_person = Person("Tetya Valya",65,"Arkhangelsk","housewife","belyashi")
somebody = Person("SheldonCooper",30,"Galveston","physicist","Thaifood")

#Information about the person (1)
my_person.introduce_yourself()

#Information about the person (2)
dictionary=my_person.__dict__
kos=dictionary.keys()
for i in kos:
    a=dictionary[i]
    print(i,": ",a)

#The last task
print("")
my_person.comparing(somebody)
# Out:
# Hey, my name is Tetya Valya, I was born in Arkhangelsk and I'm 65 years old.
# Fashion is my profession, but I'm also a housewife. I can eat belyashi all the time.
# name :  Tetya Valya
# age :  65
# citizenship :  Arkhangelsk
# profession :  housewife
# fav_food :  belyashi
#
# Tetya Valya is 35 years older than SheldonCooper

# %% [markdown]
# ## Студенческий класс
#
# * Начните с вашей программы из класса Person.
# * Создайте новый класс под названием Student, который наследуется от Person.
# * Определите некоторые качества, которые есть у учащегося, которых нет у других людей.
#     У учащегося есть школа, с которой он связан, год выпуска, средний балл и другие особые атрибуты.
# * Создайте объект Student и докажите, что вы правильно использовали наследование.
# * Установите некоторые значения атрибутов для учащегося, которые закодированы только в классе Person.
# * Установите некоторые значения атрибутов для учащегося, которые закодированы только в классе учащегося.
# * Выведите значения для всех этих атрибутов.

# %%
import string
import random

class Person():
    def __init__(self, name="Harry", age=11, citizenship= "Little Whinging", profession="Boy-Who-Lived", fav_food="Dursley's Blood"):
        self.name = name
        self.age = age
        self.citizenship = citizenship
        self.profession = profession
        self.fav_food = fav_food
    def introduce_yourself(self):
        iy=print("Hey, my name is %s, I was born in %s and I'm %d years old.\nFashion is my profession, but I'm also a %s. I can eat %s all the time."%(self.name, self.citizenship, self.age, self.profession,self.fav_food))
        return iy
    def age_person(self):
        self.age+=1
    def comparing(self,other_person):
        if self.age==other_person.age:
            a=("%s and %s are the same age"%(self.name,other_person.name))
            return a
        else:
            if self.age>other_person.age:
                dif=self.age-other_person.age
                q=("%s is %d years older than %s"%(self.name,dif,other_person.name))
                return q
            else:
                dif=other_person.age-self.age
                q=("%s is %d years younger than %s"%(self.name,dif,other_person.name))
                return q

class Student(Person):
    def __init__(self, name="Harry", age=11, citizenship= "Little Whinging", profession="Boy-Who-Lived", fav_food="Dursley's Blood",uni="Hogwarts",gpa=0,spec="WhoKnows"):
        super().__init__(name, age,citizenship,profession,fav_food)
        self.uni=uni
        self.gpa=gpa
        self.specialization=spec
    def set_parent_at(self,name, age,citizenship,profession,fav_food):
        self.name = name
        self.age = age
        self.citizenship = citizenship
        self.profession = profession
        self.fav_food = fav_food
    def set_child_at(self,uni,gpa,spec):
        self.uni=uni
        self.gpa=gpa
        self.specialization=spec

person=Person()
studentik=Student()


#INHERITANCE(check)

#First method for cheking
print("Task 1 (Solution 1)")
child_dictionary=studentik.__dict__
child_keys=list(child_dictionary.keys())
parent_dictionary=person.__dict__
parent_keys=list(parent_dictionary.keys())
a=0
for i in parent_keys:
    if child_dictionary.get(i)==None:
        print("Oooooops!")
    else:
        a+=1
if a==len(parent_keys):
    print("We are fine")
#Second method
print("")
print("Task 1 (Solution 2)")
TF=issubclass(Student,Person)
print("Did we use inheritance correctly?  ",TF)

#Changing Parent's and Child's attributes

#First solution - if we don't add extra methods in Classes and don't care about values we assign to attributes
pAttr=[]
chAttr=[]
for i in child_keys:
    if i in parent_keys:
        pAttr.append(i)
    if i not in parent_keys: 
        chAttr.append(i)
for w in chAttr:
    if w!="gpa":
        letters=[random.choice(string.ascii_letters) for x in range(0,5)]
        setattr(studentik, w, "".join(letters))
    else:
        setattr(studentik,w,2)
for w in pAttr:
    if w!="age":
        letters=[random.choice(string.ascii_letters) for x in range(0,5)]
        setattr(studentik, w, "".join(letters))
    else:
        setattr(studentik,w,20)
print("")
print("Task 2 (Solution 1)")
for i in child_keys:
    a=child_dictionary[i]
    print(i,": ",a)

#Second solution - using methods
print("")
print("Task 2 (Solution 2)")
studentik.set_parent_at("Tetya Valya",60,"Arkhangelsk","housewife","belyashi")
studentik.set_child_at("Peter the Great St.Petersburg Polytechnic University",5,"Radiophysics")
for i in child_keys:
    a=child_dictionary[i]
    print(i,": ",a)
# Out:
# Task 1 (Solution 1)
# We are fine
#
# Task 1 (Solution 2)
# Did we use inheritance correctly?   True
#
# Task 2 (Solution 1)
# name :  RKmKa
# age :  20
# citizenship :  QkqjH
# profession :  LIbcF
# fav_food :  ltzzy
# uni :  iJHpI
# gpa :  2
# specialization :  EkSSr
#
# Task 2 (Solution 2)
# name :  Tetya Valya
# age :  60
# citizenship :  Arkhangelsk
# profession :  housewife
# fav_food :  belyashi
# uni :  Peter the Great St.Petersburg Polytechnic University
# gpa :  5
# specialization :  Radiophysics
